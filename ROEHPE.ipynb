# %%
import collections
import random
import pandas as pd
import math
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime
from sklearn.linear_model import LinearRegression
import cvxpy as cp
from joblib import Parallel, delayed

# %%
def MAE(pred, true):
    return np.mean(np.abs(pred - true))

def MSE(pred, true):
    return np.mean((pred - true) ** 2)

def RMSE(pred, true):
    return np.sqrt(MSE(pred, true))

def MAPE(pred, true):
    return np.mean(np.abs((pred - true) / true))

def MSPE(pred, true):
    return np.mean(np.square((pred - true) / true))

def DA(pred, true):
    da = (pred[1:] - true[:-1]) * (true[1:] - pred[:-1]) > 0
    return da.mean()

def metric(pred, true):
    mae = MAE(pred, true)
    mse = MSE(pred, true)
    rmse = RMSE(pred, true)
    mape = MAPE(pred, true)
    mspe = MSPE(pred, true)
    da = DA(pred, true)
    
    return mae, mse, rmse, mape, mspe, da

# %%
root_path=r'datasets/'
data_path=r'gefcom2017.csv'
df = pd.read_csv(os.path.join(root_path, data_path), encoding='gb18030')
df['trend'] = range(1,len(df)+1)
# df = df[['trend','ts', 'zone', 'demand', 'drybulb', 'dewpnt', ]]
df = df[['ts', 'trend', 'zone', 'demand', 'drybulb', 'dewpnt' ]]
df['ts'] = pd.to_datetime(df['ts'])

df['RH'] = 100 * ( ((17.27 * ((df['dewpnt'] - 32 )/1.8) ) / (
    ((df['dewpnt'] - 32 )/1.8) + 237.3)).apply(math.exp) / (
    (17.27 * ((df['drybulb'] - 32 )/1.8) ) / (
         ((df['drybulb'] - 32 )/1.8) + 237.3)).apply(math.exp) )

df = df.drop(columns=['dewpnt'])

df['drybulb^2'] = df['drybulb'].apply(lambda x: x**2)
df['drybulb^3'] = df['drybulb'].apply(lambda x: x**3)

df['RH^2'] = df['RH'].apply(lambda x: x**2)
df['RH^3'] = df['RH'].apply(lambda x: x**3)

df['month'] = df['ts'].apply(lambda x: x.month - 1)
df['week'] = df['ts'].apply(lambda x: x.weekday())
df['hour'] = df['ts'].apply(lambda x: x.hour)

start = pd.Timestamp(2008, 1, 1)
end = pd.Timestamp(2017, 1, 1)
df = df.loc[df['ts'].apply(lambda x: start<= x < end )]

data_path=r'datasets/ISONE2017-2024.csv'

df2 = pd.read_csv(data_path, encoding='gb18030')
df2['ts'] = df2['ts'].apply(lambda x: pd.Timestamp(x) )

df2['RH'] = 100 * ( ((17.27 * ((df2['dewpnt'] - 32 )/1.8) ) / (
    ((df2['dewpnt'] - 32 )/1.8) + 237.3)).apply(math.exp) / (
    (17.27 * ((df2['drybulb'] - 32 )/1.8) ) / (
         ((df2['drybulb'] - 32 )/1.8) + 237.3)).apply(math.exp) )

df2 = df2.drop(columns=['dewpnt'])

df2['drybulb^2'] = df2['drybulb'].apply(lambda x: x**2)
df2['drybulb^3'] = df2['drybulb'].apply(lambda x: x**3)

df2['RH^2'] = df2['RH'].apply(lambda x: x**2)
df2['RH^3'] = df2['RH'].apply(lambda x: x**3)

df2 = df2[['ts',  'zone', 'demand', 'drybulb', 'RH', 'drybulb^2', 'drybulb^3', 'RH^2', 'RH^3', 'month', 'week', 'hour']]

# %%
def get_zone_train(df1, df2, zone, train_start, train_end, valid_start, valid_end, test_start, test_end, log=False, num_hour = 3, num_day = 1, num_hour_RH = 3, num_day_RH = 1, RH = False):
    if zone != 'MASS':
        df_ct1 = df1.groupby('zone').get_group(zone)
        df_ct2 = df2.groupby('zone').get_group(zone)
        df_ct = pd.concat([df_ct1, df_ct2])
    else:
        df_ct = df1.groupby('zone').get_group(zone)

    df_ct = df_ct.drop(columns=['zone'])
    df_ct = df_ct.loc[df_ct['ts'].apply(lambda x: train_start - datetime.timedelta(days=240) <= x < test_end )]
    
    df_ct['trend'] = range(1,len(df_ct)+1)
    df_ct = df_ct[['trend', 'ts' , 'demand', 'drybulb', 'RH', 'drybulb^2', 'drybulb^3', 'RH^2', 'RH^3', 'month', 'week', 'hour']]
    
    if RH != True:
        df_ct = df_ct.drop(columns=['RH', 'RH^2', 'RH^3'])

    df_ct = pd.get_dummies(df_ct, columns = ['month', 'hour', 'week'])
    
    for i in range(num_hour):
        df_ct['drybulb_lag{}'.format(i+1)] = df_ct['drybulb'].shift(axis=0, periods=i+1)
        df_ct['drybulb^2_lag{}'.format(i+1)] = df_ct['drybulb^2'].shift(axis=0, periods=i+1)
        df_ct['drybulb^3_lag{}'.format(i+1)] = df_ct['drybulb^3'].shift(axis=0, periods=i+1)

    for k in range(num_day):
        df_ct['drybulb^a_lag{}'.format(k)] = 0
        for j in range(24):
            df_ct['drybulb^a_lag{}'.format(k)] += df_ct['drybulb'].shift(axis=0, periods= 24 * k + j + 1)

        df_ct['drybulb^a_lag{}'.format(k)] /= 24

        df_ct['drybulb^a^2_lag{}'.format(k)] = df_ct['drybulb^a_lag{}'.format(k)].apply(lambda x: x**2)
        df_ct['drybulb^a^3_lag{}'.format(k)] = df_ct['drybulb^a_lag{}'.format(k)].apply(lambda x: x**3)

    if RH == True:
        for i in range(num_hour_RH):
            df_ct['RH_lag{}'.format(i+1)] = df_ct['RH'].shift(axis=0, periods=i+1)
            df_ct['RH^2_lag{}'.format(i+1)] = df_ct['RH^2'].shift(axis=0, periods=i+1)
            df_ct['RH^3_lag{}'.format(i+1)] = df_ct['RH^3'].shift(axis=0, periods=i+1)

        for k in range(num_day_RH):
            df_ct['RH^a_lag{}'.format(k)] = 0
            for j in range(24):
                df_ct['RH^a_lag{}'.format(k)] += df_ct['RH'].shift(axis=0, periods= 24 * k + j + 1)

            df_ct['RH^a_lag{}'.format(k)] /= 24

            df_ct['RH^a^2_lag{}'.format(k)] = df_ct['RH^a_lag{}'.format(k)].apply(lambda x: x**2)
            df_ct['RH^a^3_lag{}'.format(k)] = df_ct['RH^a_lag{}'.format(k)].apply(lambda x: x**3)
    
    train_data = df_ct.loc[df_ct['ts'].apply(lambda x: train_start <= x < train_end)]
    valid_data = df_ct.loc[df_ct['ts'].apply(lambda x: valid_start <= x < valid_end)]
    test_data = df_ct.loc[df_ct['ts'].apply(lambda x: test_start <= x < test_end)]
    
    if log:
        print("Total Set, (Nums, Variables):", df_ct.shape)
    
    X_train, y_train = train_data.drop(columns=['ts', 'demand']
                                      ).values.copy(), train_data['demand'].values.copy()
    X_valid, y_valid = valid_data.drop(columns=['ts', 'demand']
                                      ).values.copy(), valid_data['demand'].values.copy()
    X_test, y_test = test_data.drop(columns=['ts', 'demand']
                                   ).values.copy(), test_data['demand'].values.copy()
    if log:
        print("zone: {}, \n\t Train start: {}, \n\t Train end: {}".format(zone, train_start, train_end))
        print("zone: {}, \n\t Valid start: {}, \n\t Valid end: {}".format(zone, valid_start, valid_end))
        print("zone: {}, \n\t Test start: {}, \n\t Test end: {}".format(zone, test_start, test_end))
        print("Train set:", X_train.shape)
        print("Valid set:", X_valid.shape)
        print("Test set:", X_test.shape)
    
    return X_train, y_train, X_valid, y_valid, X_test, y_test

# %%
class AltPoly():
    def __init__(self, n4=1, n3=1, n2=1 ,n1=1, device = 'cuda'):
        # 定义自变量
        self.n1 = n1
        self.n2 = n2
        self.n3 = n3
        self.n4 = n4
        # 判断设备信息
        if device == ('cuda') or ('cpu'):
            print('you are using:',device)
        else:
            raise Exception('please select the correct device name, "cuda" or "cpu"')
        self.device = device
        
    # 初始化输入变量
    def initial_input(self, X_train, y_train, X_test, y_test):
        self.n = X_train.shape[0] # 有n个样本
        self.m = X_train.shape[1] # 有m个特征
        self.n_test = X_test.shape[0] # 有n个样本
        self.X = torch.tensor(X_train).to(torch.device(self.device))
        self.y = torch.tensor(y_train).to(torch.device(self.device))
        self.X_test = torch.tensor(X_test).to(torch.device(self.device))

        # test set numpy
        self.y_test = y_test
        self.y_train = y_train

    def initial_param(self):
        std = 1
        self.w41 = torch.normal(0, std, (self.m - 1, self.n4), device = torch.device(self.device), dtype = torch.float64)
        self.w42 = torch.normal(0, std, (self.m - 1, self.n4), device = torch.device(self.device), dtype = torch.float64)
        self.w43 = torch.normal(0, std, (self.m - 1, self.n4), device = torch.device(self.device), dtype = torch.float64)
        self.w44 = torch.normal(0, std, (self.m - 1, self.n4), device = torch.device(self.device), dtype = torch.float64)

        self.w31 = torch.normal(0, std, (self.m - 1, self.n3), device = torch.device(self.device), dtype = torch.float64)
        self.w32 = torch.normal(0, std, (self.m - 1, self.n3), device = torch.device(self.device), dtype = torch.float64)
        self.w33 = torch.normal(0, std, (self.m - 1, self.n3), device = torch.device(self.device), dtype = torch.float64)

        self.w21 = torch.normal(0, std, (self.m - 1, self.n2), device = torch.device(self.device), dtype = torch.float64)
        self.w22 = torch.normal(0, std, (self.m - 1, self.n2), device = torch.device(self.device), dtype = torch.float64)

        self.w11 = torch.normal(0, std, (self.m, 1), device = torch.device(self.device), dtype = torch.float64)
        self.w00 = torch.zeros(1, device = torch.device(self.device), dtype=torch.float64)

    def net4(self, w1, w2, w3, w4, X):
        tem1 = ( X[:,1:] @ w1 ).sum(axis = 1).reshape(-1, 1)
        tem2 = ( X[:,1:] @ w2 ).sum(axis = 1).reshape(-1, 1)
        tem3 = ( X[:,1:] @ w3 ).sum(axis = 1).reshape(-1, 1)
        tem4 = ( X[:,1:] @ w4 ).sum(axis = 1).reshape(-1, 1)
        tem = ( tem1 * tem2 * tem3 * tem4 ).sum(axis = 1).reshape(-1)
        return tem, tem1, tem2, tem3, tem4

    def net3(self, w1, w2, w3, X):
        tem1 = ( X[:,1:] @ w1 ).sum(axis = 1).reshape(-1, 1)
        tem2 = ( X[:,1:] @ w2 ).sum(axis = 1).reshape(-1, 1)
        tem3 = ( X[:,1:] @ w3 ).sum(axis = 1).reshape(-1, 1)
        tem = ( tem1 * tem2 * tem3).reshape(-1)
        return tem, tem1, tem2, tem3

    def net2(self, w1, w2, X):
        tem1 = ( X[:,1:] @ w1 ).sum(axis = 1).reshape(-1, 1)
        tem2 = ( X[:,1:] @ w2 ).sum(axis = 1).reshape(-1, 1)
        tem = ( tem1 * tem2).reshape(-1)
        return tem, tem1, tem2

    def net1(self, w11, w00, X):
        X11 = ( X @ w11 ).reshape(-1)
        return X11 + w00

    def net(self, w41, w42, w43, w44, w31, w32, w33, w21, w22, w11, w00, X):
        return self.net4(w41, w42, w43, w44, X)[0] + self.net3(w31, w32, w33, X)[0] + self.net2(w21, w22, X)[0] + self.net1(w11, w00, X)
    
    # 优化过程，输入迭代次数
    def optimize(self, num_subepoch = 60, num_epoch = 60, printstride = 10, steplag = False, valid = False):
        
        losslist = [float('inf') for i in range(10)]
        
        for EPOCH in range(num_epoch):
            
            f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
            f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
            f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
            f1 = self.net1(self.w11, self.w00, self.X)
            f = (f1 + f2 + f3 + f4)

            w11_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * self.X ).sum(axis = [0]) ).reshape(-1,1) / ( self.n )
            w00_grad = ( ( 2 * (f - self.y) ).sum() ) / ( self.n )
            w21_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f22 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            w31_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f32 * f33 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            w41_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f42 * f43 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            dw11 = [-w11_grad, 0]
            dw00 = [-w00_grad, 0]
            dw21 = [-w21_grad, 0]
            dw31 = [-w31_grad, 0]
            dw41 = [-w41_grad, 0]
            
            gklist = [0 ,0 , (torch.norm(w11_grad))**2 + (torch.norm(w00_grad))**2 + (torch.norm(w21_grad))**2  
                      + (torch.norm(w31_grad))**2 + (torch.norm(w41_grad))**2 ]
            
            for epoch in range(num_subepoch):

                lr = gklist[-1] / ( 2 * ( (self.net1(dw11[0], dw00[0], self.X ) 
                                           + self.net2(dw21[0], self.w22, self.X )[0] 
                                              + self.net3(dw31[0], self.w32, self.w33, self.X )[0] 
                                              + self.net4(dw41[0], self.w42, self.w43, self.w44, self.X )[0] )**2 ).sum() / (self.n) )
                self.w11 += lr * dw11[0] 
                self.w00 += lr * dw00[0] 
                self.w21 += lr * dw21[0]
                self.w31 += lr * dw31[0]
                self.w41 += lr * dw41[0]
                                   
                f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
                f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
                f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
                f1 = self.net1(self.w11, self.w00, self.X)
                f = (f1 + f2 + f3 + f4)

                w11_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * self.X ).sum(axis = [0]) ).reshape(-1,1) / ( self.n )
                w00_grad = ( ( 2 * (f - self.y) ).sum() ) / ( self.n )
                w21_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f22 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                w31_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f32 * f33 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                w41_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f42 * f43 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                
                gklist.append( (torch.norm(w11_grad))**2 + (torch.norm(w00_grad))**2 + (torch.norm(w21_grad))**2  
                      + (torch.norm(w31_grad))**2 + (torch.norm(w41_grad))**2 )
                
                beta = gklist[-1] / gklist[-2]

                dw11[1] = dw11[0]
                dw11[0] = -w11_grad + beta * dw11[1]
                
                dw00[1] = dw00[0]
                dw00[0] = -w00_grad + beta * dw00[1]
                
                dw21[1] = dw21[0]
                dw21[0] = - w21_grad + beta * dw21[1]
                
                dw31[1] = dw31[0]
                dw31[0] = - w31_grad + beta * dw31[1]
                
                dw41[1] = dw41[0]
                dw41[0] = - w41_grad + beta * dw41[1]
                
            # 第二轮   
            f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
            f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
            f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
            f1 = self.net1(self.w11, self.w00, self.X)
            f = (f1 + f2 + f3 + f4)

            w22_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f21 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            w32_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f31 * f33 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            w42_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f43 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            dw22 = [-w22_grad, 0]
            dw32 = [-w32_grad, 0]
            dw42 = [-w42_grad, 0]
            
            gklist = [ 0 ,0 , (torch.norm(w22_grad))**2 + (torch.norm(w32_grad))**2 + (torch.norm(w42_grad))**2 ]
            
            for epoch in range(num_subepoch):

                lr = gklist[-1] / ( ( 2 * ( self.net2(dw22[0], self.w21, self.X )[0] 
                                            + self.net3(dw32[0], self.w31, self.w33, self.X )[0] 
                                            + self.net4(dw42[0], self.w41, self.w43, self.w44, self.X )[0] )**2 ).sum() / (self.n) )
                self.w22 += lr * dw22[0]
                self.w32 += lr * dw32[0]
                self.w42 += lr * dw42[0]
                                   
                f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
                f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
                f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
                f1 = self.net1(self.w11, self.w00, self.X)
                f = (f1 + f2 + f3 + f4)

                w22_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f21 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                w32_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f31 * f33 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                w42_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f43 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                
                gklist.append( (torch.norm(w22_grad))**2 + (torch.norm(w32_grad))**2 + (torch.norm(w42_grad))**2 )
                
                beta = gklist[-1] / gklist[-2]
                
                dw22[1] = dw22[0]
                dw22[0] = - w22_grad + beta * dw22[1]
                
                dw32[1] = dw32[0]
                dw32[0] = - w32_grad + beta * dw32[1]
                
                dw42[1] = dw42[0]
                dw42[0] = - w42_grad + beta * dw42[1]
            
            
            if steplag == True:
                if ( ( EPOCH + 1 ) % printstride == 0 ) and ( (epoch + 1 ) % num_subepoch == 0 ) :

                    predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test).to(torch.device('cpu')).numpy()

                    predict_y_train = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X).to(torch.device('cpu')).numpy()

                    test_RMSE = RMSE(predict_y_test.reshape(self.y_test.shape), self.y_test)
                    train_MSE = MSE(predict_y_train.reshape(self.y_train.shape), self.y_train)
                    test_MAPE = MAPE(predict_y_test.reshape(self.y_test.shape), self.y_test)

                    self.test_MAPE = test_MAPE
                    self.test_RMSE = test_RMSE
                    self.predict_y_test = predict_y_test
                    self.predict_y_train = predict_y_train

                    print('epoch',epoch+1,'w11, w00','EPOCH',EPOCH + 1,
                          '\n TEST RMSE', test_RMSE,
                          '\n TRAIN MSE',train_MSE,
                          '\n TEST MAPE',100*test_MAPE)
                    print(" ")
                    
            # 第三轮
            f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
            f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
            f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
            f1 = self.net1(self.w11, self.w00, self.X)
            f = (f1 + f2 + f3 + f4)

            w33_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f31 * f32 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            w43_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f42 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            dw33 = [-w33_grad, 0]
            dw43 = [-w43_grad, 0]
            
            gklist = [ 0 ,0 , (torch.norm(w33_grad))**2 + (torch.norm(w43_grad))**2 ]
            
            for epoch in range(num_subepoch):

                lr = gklist[-1] / ( ( 2 * ( self.net3(dw33[0], self.w31, self.w32, self.X )[0] 
                                            + self.net4(dw43[0], self.w41, self.w42, self.w44, self.X )[0] )**2 ).sum() / (self.n) )
                self.w33 += lr * dw33[0]
                self.w43 += lr * dw43[0]
                                   
                f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
                f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
                f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
                f1 = self.net1(self.w11, self.w00, self.X)
                f = (f1 + f2 + f3 + f4)

                w33_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f31 * f32 * self.X[:,1:] ).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                w43_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f42 * f44 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                
                gklist.append( (torch.norm(w33_grad))**2 + (torch.norm(w43_grad))**2 )
                
                beta = gklist[-1] / gklist[-2]
                
                dw33[1] = dw33[0]
                dw33[0] = - w33_grad + beta * dw33[1]
                
                dw43[1] = dw43[0]
                dw43[0] = - w43_grad + beta * dw43[1]
            
            
            if steplag == True:
                if ( ( EPOCH + 1 ) % printstride == 0 ) and ( (epoch + 1 ) % num_subepoch == 0 ) :

                    predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test).to(torch.device('cpu')).numpy()

                    predict_y_train = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X).to(torch.device('cpu')).numpy()

                    test_RMSE = RMSE(predict_y_test.reshape(self.y_test.shape), self.y_test)
                    train_MSE = MSE(predict_y_train.reshape(self.y_train.shape), self.y_train)
                    test_MAPE = MAPE(predict_y_test.reshape(self.y_test.shape), self.y_test)

                    self.test_MAPE = test_MAPE
                    self.test_MSE = test_RMSE
                    self.predict_y_test = predict_y_test
                    self.predict_y_train = predict_y_train

                    print('epoch',epoch+1,'w11, w00','EPOCH',EPOCH + 1,
                          '\n TEST RMSE', test_RMSE,
                          '\n TRAIN MSE',train_MSE,
                          '\n TEST MAPE',100*test_MAPE)
                    print(" ")
                    
            # 第四轮
            f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
            f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
            f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
            f1 = self.net1(self.w11, self.w00, self.X)
            f = (f1 + f2 + f3 + f4)

            w44_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f42 * f43 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
            dw44 = [-w44_grad, 0]
            
            gklist = [ 0 ,0 , (torch.norm(w44_grad))**2 ]
            
            for epoch in range(num_subepoch):

                lr = gklist[-1] / ( ( 2 * ( self.net4(dw44[0], self.w41, self.w42, self.w43, self.X )[0] )**2 ).sum() / (self.n) )
                self.w44 += lr * dw44[0]
                                   
                f4, f41, f42, f43, f44 = self.net4(self.w41, self.w42, self.w43, self.w44, self.X)
                f3, f31, f32, f33 = self.net3(self.w31, self.w32, self.w33, self.X)
                f2, f21, f22 = self.net2(self.w21, self.w22, self.X)
                f1 = self.net1(self.w11, self.w00, self.X)
                f = (f1 + f2 + f3 + f4)
                
                w44_grad =  ( ( ( 2 * (f - self.y) ).reshape(-1,1) * f41 * f42 * f43 * self.X[:,1:]).sum(axis = [0]) ).reshape(-1, 1) / ( self.n )
                
                gklist.append( (torch.norm(w44_grad) )**2 )
                
                beta = gklist[-1] / gklist[-2]
                
                dw44[1] = dw44[0]
                dw44[0] = - w44_grad + beta * dw44[1]
            
            
            if steplag == True:
                if ( ( EPOCH + 1 ) % printstride == 0 ) and ( (epoch + 1 ) % num_subepoch == 0 ) :

                    predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test).to(torch.device('cpu')).numpy()

                    predict_y_train = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                     self.w33, self.w21, self.w22, self.w11, self.w00, self.X).to(torch.device('cpu')).numpy()

                    test_RMSE = RMSE(predict_y_test.reshape(self.y_test.shape), self.y_test)
                    train_MSE = MSE(predict_y_train.reshape(self.y_train.shape), self.y_train)
                    test_MAPE = MAPE(predict_y_test.reshape(self.y_test.shape), self.y_test)

                    self.test_MAPE = test_MAPE
                    self.test_RMSE = test_RMSE
                    self.predict_y_test = predict_y_test
                    self.predict_y_train = predict_y_train

                    print('epoch',epoch+1,'w11, w00','EPOCH',EPOCH + 1,
                          '\n TEST RMSE', test_RMSE,
                          '\n TRAIN MSE',train_MSE,
                          '\n TEST MAPE',100*test_MAPE)
                    print(" ")
            
            predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
             self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test)
            
            if valid == True:
                losslist.append( ( ((predict_y_test.to(torch.device('cpu')).numpy()
                                    ).reshape(self.y_test.shape) - self.y_test)**2 ).sum()/self.n )
                if (losslist[-1] > losslist[-2]) and (losslist[-2] > losslist[-3]) and (losslist[-3] > losslist[-4]):   
                    self.epoch = EPOCH - 3
                    break
            
            if ( ( EPOCH + 1 ) % printstride == 0 ) and ( (epoch + 1 ) % num_subepoch == 0 ) :

                predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                    self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test).to(torch.device('cpu')).numpy()

                predict_y_train = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
                    self.w33, self.w21, self.w22, self.w11, self.w00, self.X).to(torch.device('cpu')).numpy()

                test_RMSE = RMSE(predict_y_test.reshape(self.y_test.shape), self.y_test)
                train_MSE = MSE(predict_y_train.reshape(self.y_train.shape), self.y_train)
                test_MAPE = MAPE(predict_y_test.reshape(self.y_test.shape), self.y_test)

                self.test_MAPE = test_MAPE
                self.test_MSE = test_RMSE
                self.predict_y_test = predict_y_test
                self.predict_y_train = predict_y_train

                print('epoch',epoch+1,'EPOCH',EPOCH + 1,
                        '\n TEST RMSE', test_RMSE,
                        '\n TRAIN MSE',train_MSE,
                        '\n TEST MAPE',100*test_MAPE)
                print(" ")
                
        predict_y_test = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
         self.w33, self.w21, self.w22, self.w11, self.w00, self.X_test).to(torch.device('cpu')).numpy()

        predict_y_train = self.net(self.w41, self.w42, self.w43, self.w44, self.w31, self.w32, 
         self.w33, self.w21, self.w22, self.w11, self.w00, self.X).to(torch.device('cpu')).numpy()

        test_RMSE = RMSE(predict_y_test.reshape(self.y_test.shape), self.y_test)
        train_MSE = MSE(predict_y_train.reshape(self.y_train.shape), self.y_train)
        test_MAPE = MAPE(predict_y_test.reshape(self.y_test.shape), self.y_test)

        self.test_MAPE = test_MAPE
        self.test_RMSE = test_RMSE
        self.predict_y_test = predict_y_test
        self.predict_y_train = predict_y_train

        print('epoch',epoch+1,'EPOCH',EPOCH + 1,
                '\n TEST RMSE', test_RMSE,
                '\n TRAIN MSE',train_MSE,
                '\n TEST MAPE',100*test_MAPE)
        print(" ")
        
        if valid == True:
            self.epoch = EPOCH + 1

# %%
import warnings
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

import sys
sys.path.append("..")
from pathlib import Path
import pickle

Path(f"./results").mkdir(parents=True, exist_ok=True)

def AltPolyRepeat(seed, train_features, train_labels, valid_features, valid_labels, num_subepoch, num_epoch, printstride, device):

    # set seed
    seed = int(seed)
    print('seed', seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    model = AltPoly(1, 1, 1 ,1, device = device)
    model.initial_input(train_features, train_labels, valid_features, valid_labels)
    model.initial_param()
    model.optimize(num_subepoch = num_subepoch, num_epoch = num_epoch, printstride = printstride, steplag = False, valid = False)
    return model.predict_y_test


start_year = 2015
num_subepoch = 20
num_epoch = 100
import time
printstride = 200
ensemble_times = 30

df_list_baseline_results = []
seed_group0 = 0
run_times = 10

seed_list = (np.arange(run_times * ensemble_times).reshape(run_times, ensemble_times)).astype(int)


for seed_group in range(seed_group0, seed_group0 + run_times):

    path = f"./results/Repeated-{seed_group}.pkl"
    
    saved_dict = {}

    for zone in ['CT', 'ME', 'NEMASSBOST', 'NH', 'RI', 'SEMASS', 'TOTAL','VT', 'WCMASS']:
        
        X_train, y_train, X_valid, y_valid, X_test, y_test = get_zone_train(
            df, df2, zone=zone,
            train_start = pd.Timestamp(start_year, 1, 1),
            train_end = pd.Timestamp(start_year + 2, 1, 1),
            valid_start = pd.Timestamp(start_year + 2, 1, 1),
            valid_end = pd.Timestamp(start_year + 3, 1, 1),
            test_start = pd.Timestamp(start_year + 3, 1, 1),
            test_end = pd.Timestamp(start_year + 4, 1, 1),
            log=True, num_hour = 24, num_day = 7, 
            num_hour_RH = 3, num_day_RH = 1, RH = True
        )

        train_features = X_train.astype(np.float64)
        valid_features = X_valid.astype(np.float64)
        test_features = X_test.astype(np.float64)

        train_labels = y_train.astype(np.float64)
        valid_labels = y_valid.astype(np.float64)
        test_labels = y_test.astype(np.float64)

        [m_train, n_train] = train_features.shape
        [m_valid, n_valid] = valid_features.shape
        [m_test, n_test] = test_features.shape

        # normalization
        X_all = np.concatenate((train_features, valid_features, test_features), axis = 0)
        m = X_all.shape[0]
        mins = np.min(X_all[0:(m_train + m_valid), :], axis = 0)
        maxs = np.max(X_all[0:(m_train + m_valid), :], axis = 0)

        for i in range(m):
            X_all[i,:] = ( X_all[i,:] - mins ) / ( maxs - mins )

        train_features = X_all[:m_train, :]
        valid_features = X_all[m_train:(m_train + m_valid), :]
        test_features = X_all[(m_train + m_valid) : , : ]

        # Since the validation set is unnecessary, it is merged with the training set.

        X_train_valid = np.concatenate((train_features, valid_features), axis = 0)
        y_train_valid = np.concatenate((train_labels, valid_labels), axis = 0)      

        time_start = time.time()

        finalresult = Parallel(n_jobs=1)(
            delayed(AltPolyRepeat)(seed, X_train_valid, y_train_valid, test_features, test_labels, num_subepoch, num_epoch, printstride, device = 'cuda') for seed in seed_list[seed_group])

        time_end = time.time()

        pre_test_ensemble = np.array(finalresult).reshape(ensemble_times, -1).mean(axis = 0)

        test_RMSE = RMSE(pre_test_ensemble.reshape(test_labels.shape), test_labels)
        test_MAPE = MAPE(pre_test_ensemble.reshape(test_labels.shape), test_labels)*100

        Daily_peak_test_RMSE = RMSE( np.max(pre_test_ensemble.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )
        Daily_peak_test_MAPE = MAPE( np.max(pre_test_ensemble.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )*100

        df_list_baseline_results.append({
            'zone': zone,
            'test_RMSE': test_RMSE,
            'test_MAPE': test_MAPE,
            'Daily_peak_test_RMSE': Daily_peak_test_RMSE,
            'Daily_peak_test_MAPE': Daily_peak_test_MAPE,
            'seed_group': seed_group
        })

        pre_metric = metric(pre_test_ensemble.reshape(test_labels.shape), test_labels)
        print(pre_metric)

        sub_saved_dict = {}
        sub_saved_dict["seed_group"] = seed_group
        sub_saved_dict["emsemble_times"] = ensemble_times
        sub_saved_dict["test_RMSE"] = test_RMSE
        sub_saved_dict["test_MAPE"] = test_MAPE
        sub_saved_dict["Daily_peak_test_RMSE"] = Daily_peak_test_RMSE
        sub_saved_dict["Daily_peak_test_MAPE"] = Daily_peak_test_MAPE
        sub_saved_dict["compute time"] = time_end - time_start
        sub_saved_dict["pre_test_load"] = pre_test_ensemble.reshape(test_labels.shape)
        sub_saved_dict["pre_metric"] = pre_metric

        # Checkpoint
        saved_dict[f"zone_{zone}"] = sub_saved_dict
        with open(path, "wb") as f:
            pickle.dump(saved_dict,
                        f,
                        protocol=pickle.HIGHEST_PROTOCOL)

        print('model rersult', 
            '\n test RMSE', test_RMSE,
            '\n test MAPE', test_MAPE,
            '\n Daily_peak_test_RMSE', Daily_peak_test_RMSE,
            '\n Daily_peak_test_MAPE', Daily_peak_test_MAPE )
        print(" ")

        # 假设模型训练完成后，进行显存清理
        torch.cuda.empty_cache()

# Process results for experiment
df_results = pd.DataFrame(df_list_baseline_results)
test_rmse_df = df_results.groupby(['zone']).agg(["mean", "std"])["test_RMSE"]
test_mape_df = df_results.groupby(['zone']).agg(["mean", "std"])["test_MAPE"]
Daily_peak_test_rmse_df = df_results.groupby(['zone']).agg(["mean", "std"])["Daily_peak_test_RMSE"]
Daily_peak_test_mape_df = df_results.groupby(['zone']).agg(["mean", "std"])["Daily_peak_test_MAPE"]

print("Test RMSE of experiment")
print(test_rmse_df)
print("Test MAPE of experiment")
print(test_mape_df)
print("Test Daily peak RMSE of experiment")
print(Daily_peak_test_rmse_df)
print("Test Daily peak MAPE of experiment")
print(Daily_peak_test_mape_df)
# Out:
# Total Set, (Nums, Variables): (40819, 157)
# zone: CT,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: CT,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: CT,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 165.23225133209738
#  TRAIN MSE 10913.570967577078
#  TEST MAPE 3.75153181839364
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.16305539413665
#  TRAIN MSE 9997.083341916026
#  TEST MAPE 3.5981394441274177
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 157.79549974714035
#  TRAIN MSE 9847.874562836689
#  TEST MAPE 3.6972016360286784
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.7859151257312
#  TRAIN MSE 11097.7558160339
#  TEST MAPE 3.517687023994192
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 155.587714238159
#  TRAIN MSE 13204.85919734927
#  TEST MAPE 3.314499849746
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.9086164026664
#  TRAIN MSE 10566.394541876207
#  TEST MAPE 3.489148291311364
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 146.4308767414495
#  TRAIN MSE 10302.573885583308
#  TEST MAPE 3.4476447456420143
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 162.1779855969469
#  TRAIN MSE 10417.779839103925
#  TEST MAPE 3.715678156636679
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 157.75816215862372
#  TRAIN MSE 11466.963993001302
#  TEST MAPE 3.5173081376482638
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 152.1030205618353
#  TRAIN MSE 10494.406588670876
#  TEST MAPE 3.5509168858114233
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 155.38373641484702
#  TRAIN MSE 10346.006356390724
#  TEST MAPE 3.6373974617354943
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.91018429681316
#  TRAIN MSE 10881.52227326346
#  TEST MAPE 3.528178540987345
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 156.69935894877315
#  TRAIN MSE 10345.787038203998
#  TEST MAPE 3.631460732641751
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.27860351345916
#  TRAIN MSE 9729.614422870309
#  TEST MAPE 3.562061620057343
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 147.7009730518451
#  TRAIN MSE 10543.93820075914
#  TEST MAPE 3.4575587581660856
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 145.92797597325438
#  TRAIN MSE 10411.169765856937
#  TEST MAPE 3.4273307648011646
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 151.62868762540927
#  TRAIN MSE 10157.187460127434
#  TEST MAPE 3.5960549000034376
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.77914222636838
#  TRAIN MSE 10448.291112686067
#  TEST MAPE 3.5222020761611885
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 153.39621813166102
#  TRAIN MSE 9793.408529882732
#  TEST MAPE 3.6031161189474545
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 138.06486488451372
#  TRAIN MSE 11315.929044513181
#  TEST MAPE 2.9576891886825933
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 144.77171093490244
#  TRAIN MSE 10648.162121789443
#  TEST MAPE 3.3279087297629335
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 146.81214146026724
#  TRAIN MSE 10939.095013051092
#  TEST MAPE 3.5104047107743113
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 152.26080435674226
#  TRAIN MSE 10264.604447740747
#  TEST MAPE 3.5635384054690196
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 142.66417340892255
#  TRAIN MSE 10312.680134733939
#  TEST MAPE 3.3974669411797445
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 146.7311287094174
#  TRAIN MSE 11503.41716676345
#  TEST MAPE 3.0960257491860843
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 160.18598802513569
#  TRAIN MSE 11106.417697475292
#  TEST MAPE 3.728167404250645
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 146.4751950044178
#  TRAIN MSE 10047.690558151648
#  TEST MAPE 3.471397664935073
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 143.07183029521346
#  TRAIN MSE 10390.183011871204
#  TEST MAPE 3.392528905494342
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.3804765190962
#  TRAIN MSE 10543.008199103437
#  TEST MAPE 3.4884451138499672
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 153.96002435733922
#  TRAIN MSE 10775.122099666192
#  TEST MAPE 3.5097903795337837
#
# (108.13326968729962, 19392.149902488774, 139.25569971275422, 0.03262031532924445, 0.001669026350298546, 0.5473227537390113)
# model rersult
#  test RMSE 139.25569971275422
#  test MAPE 3.262031532924445
#  Daily_peak_test_RMSE 152.51967355478644
#  Daily_peak_test_MAPE 2.7209674145577343
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: ME,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: ME,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: ME,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.29141023295465
#  TRAIN MSE 1459.473974215963
#  TEST MAPE 3.985504791424297
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 64.81936482193615
#  TRAIN MSE 1594.155750955673
#  TEST MAPE 3.807673759597037
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 77.51572984631233
#  TRAIN MSE 1482.2076371931541
#  TEST MAPE 4.266568547953944
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 66.35098237925195
#  TRAIN MSE 1480.4281109282222
#  TEST MAPE 3.8814256785754453
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 57.49819958422921
#  TRAIN MSE 1709.5944474764935
#  TEST MAPE 3.4234171706433782
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 65.92687612493583
#  TRAIN MSE 1533.6783834004877
#  TEST MAPE 3.910591813523011
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 66.5444533179364
#  TRAIN MSE 1459.8546582778918
#  TEST MAPE 3.95180656281928
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 66.4701104932759
#  TRAIN MSE 1445.847896675383
#  TEST MAPE 4.009492603082706
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 66.42954382667948
#  TRAIN MSE 1531.9503102531426
#  TEST MAPE 3.990982087764494
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 66.99543349662433
#  TRAIN MSE 1555.9471692111827
#  TEST MAPE 3.98523148046868
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.96146983096692
#  TRAIN MSE 1435.820994558708
#  TEST MAPE 4.072726030161681
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 67.03116762368661
#  TRAIN MSE 1637.273772124268
#  TEST MAPE 3.9084654553635994
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.03070138983352
#  TRAIN MSE 1555.7241676979515
#  TEST MAPE 4.058103385196493
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 67.80875193218371
#  TRAIN MSE 1446.6366043512332
#  TEST MAPE 4.0504208626700695
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 67.93360995352958
#  TRAIN MSE 1467.0270211056072
#  TEST MAPE 4.068653706364501
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 69.9789365625818
#  TRAIN MSE 1474.1028765534206
#  TEST MAPE 4.024258834575271
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 67.70575232069294
#  TRAIN MSE 1435.0733731600856
#  TEST MAPE 4.097423831365211
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.85220206740435
#  TRAIN MSE 1432.9064766431427
#  TEST MAPE 4.06488874812365
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 65.7698346224904
#  TRAIN MSE 1470.8262266822353
#  TEST MAPE 3.9417331546645875
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 55.36823517274679
#  TRAIN MSE 1535.5381903496113
#  TEST MAPE 3.3228893519813423
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 71.79042267820607
#  TRAIN MSE 1454.7111172126015
#  TEST MAPE 4.141586110595513
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.18816309769937
#  TRAIN MSE 1475.2466398804534
#  TEST MAPE 4.050657517297057
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 73.28357207460016
#  TRAIN MSE 1511.7217710608697
#  TEST MAPE 4.160502478601051
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 67.79438229704861
#  TRAIN MSE 1445.7475020069771
#  TEST MAPE 3.9834443316127297
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 60.87845724340915
#  TRAIN MSE 1532.156178256216
#  TEST MAPE 3.5551890233537997
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 68.29851129038778
#  TRAIN MSE 1495.9573389479067
#  TEST MAPE 4.03750596499305
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 69.8292329911559
#  TRAIN MSE 1379.5068983699987
#  TEST MAPE 4.108770985707441
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 71.58168639635335
#  TRAIN MSE 1357.3473803473048
#  TEST MAPE 4.1628328100782275
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 72.037868939807
#  TRAIN MSE 1505.1123224068679
#  TEST MAPE 4.111631978702658
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 69.10874275516503
#  TRAIN MSE 1436.8118077510715
#  TEST MAPE 4.100382088939543
#
# (51.24753793515935, 4145.094261307467, 64.38240645787843, 0.038233574302718364, 0.0021791887649515473, 0.4357803402214865)
# model rersult
#  test RMSE 64.38240645787843
#  test MAPE 3.8233574302718365
#  Daily_peak_test_RMSE 72.61850134860644
#  Daily_peak_test_MAPE 3.7614369481335057
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: NEMASSBOST,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: NEMASSBOST,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: NEMASSBOST,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.59004487838301
#  TRAIN MSE 6553.32280639066
#  TEST MAPE 3.4221611560908185
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 125.39363486654203
#  TRAIN MSE 7303.004861794088
#  TEST MAPE 3.438178519529745
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 121.11243121567331
#  TRAIN MSE 6185.527927795768
#  TEST MAPE 3.3372830610864592
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 125.3747706335426
#  TRAIN MSE 7001.452732428817
#  TEST MAPE 3.274736797128471
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 140.36728890704842
#  TRAIN MSE 8206.325635694362
#  TEST MAPE 3.4975591867718134
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.47970938899388
#  TRAIN MSE 6467.7966669981415
#  TEST MAPE 3.3829818173886474
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.28873964886827
#  TRAIN MSE 6575.3804056738445
#  TEST MAPE 3.329828405196581
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 118.78129431740358
#  TRAIN MSE 6637.667772040977
#  TEST MAPE 3.284242589285883
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 126.46911867297976
#  TRAIN MSE 6732.187787364609
#  TEST MAPE 3.4058004402596342
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 119.02946367708421
#  TRAIN MSE 6657.995359188002
#  TEST MAPE 3.240295938317269
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 120.7072798732904
#  TRAIN MSE 6820.496770163129
#  TEST MAPE 3.3278785220146183
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.9719503978574
#  TRAIN MSE 7120.948516602588
#  TEST MAPE 3.3408502299222396
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 120.0836446408308
#  TRAIN MSE 6781.571410906454
#  TEST MAPE 3.319841880030925
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.10929676760213
#  TRAIN MSE 7073.255475795949
#  TEST MAPE 3.39588510690889
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 121.91082571468372
#  TRAIN MSE 6899.011442246033
#  TEST MAPE 3.3839660966952554
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 119.36514184426537
#  TRAIN MSE 6581.384368206432
#  TEST MAPE 3.314225016002037
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.1447437497216
#  TRAIN MSE 6736.392171954754
#  TEST MAPE 3.347290121390767
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 121.08074912987557
#  TRAIN MSE 6390.004429390084
#  TEST MAPE 3.2959364868296834
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 121.47725758049128
#  TRAIN MSE 6395.979525021616
#  TEST MAPE 3.3254307501266145
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 133.42582834320663
#  TRAIN MSE 8004.808406010239
#  TEST MAPE 3.2979678321372456
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 117.19436489568788
#  TRAIN MSE 6383.397203760519
#  TEST MAPE 3.185829300805166
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 120.65856885202358
#  TRAIN MSE 6483.297495264403
#  TEST MAPE 3.3520425177465167
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 129.15001349632928
#  TRAIN MSE 6587.348641267834
#  TEST MAPE 3.4803042248990668
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 124.83726689048565
#  TRAIN MSE 6795.528481753132
#  TEST MAPE 3.4205336313458297
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 137.37405524715638
#  TRAIN MSE 7708.525108621247
#  TEST MAPE 3.4400507941753684
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 134.91050180713717
#  TRAIN MSE 6774.753212931742
#  TEST MAPE 3.465567003341049
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 120.13418815299326
#  TRAIN MSE 6256.279702153896
#  TEST MAPE 3.321116722884834
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 122.3470604703818
#  TRAIN MSE 6592.442378496226
#  TEST MAPE 3.3714505770298206
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 121.78260996289582
#  TRAIN MSE 6581.545834418151
#  TEST MAPE 3.3721385785587894
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 120.77163823412768
#  TRAIN MSE 6669.690149725114
#  TEST MAPE 3.2913403777774914
#
# (86.91686840906345, 12995.111159058657, 113.99610150815973, 0.03082414632656324, 0.001514631608503826, 0.5168398218974769)
# model rersult
#  test RMSE 113.99610150815973
#  test MAPE 3.0824146326563238
#  Daily_peak_test_RMSE 133.4359094777682
#  Daily_peak_test_MAPE 2.954000266714712
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: NH,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: NH,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: NH,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.63251161279251
#  TRAIN MSE 1410.1825222472269
#  TEST MAPE 2.5428154613169225
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.06256526901879
#  TRAIN MSE 1281.9492358389973
#  TEST MAPE 2.6743516323342953
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.234915812766275
#  TRAIN MSE 1391.4923164517684
#  TEST MAPE 2.6055342592268413
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.003069564409245
#  TRAIN MSE 1283.9629824652175
#  TEST MAPE 2.560742273253282
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 43.866646812952894
#  TRAIN MSE 1567.4592834122066
#  TEST MAPE 2.3685645681782415
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.68843787118271
#  TRAIN MSE 1303.1777965999115
#  TEST MAPE 2.5540237933584753
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 43.9682348368521
#  TRAIN MSE 1317.4909883318328
#  TEST MAPE 2.5101081295329
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.475070351652946
#  TRAIN MSE 1256.3020528114862
#  TEST MAPE 2.677580169962778
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 49.58592464864241
#  TRAIN MSE 1461.5654827242065
#  TEST MAPE 2.7404451481308425
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.724898365101694
#  TRAIN MSE 1329.3331057827531
#  TEST MAPE 2.5354853742100802
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.82424918929023
#  TRAIN MSE 1273.3534615185545
#  TEST MAPE 2.552167409964965
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.90562457929968
#  TRAIN MSE 1385.049275828899
#  TEST MAPE 2.5498193108436715
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.03413957989742
#  TRAIN MSE 1364.0315887340155
#  TEST MAPE 2.7132193893530365
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.58504643607746
#  TRAIN MSE 1221.3527096737052
#  TEST MAPE 2.6157249140687884
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.42494736711149
#  TRAIN MSE 1307.85026454854
#  TEST MAPE 2.591998044145181
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.599323254416056
#  TRAIN MSE 1313.5376860829103
#  TEST MAPE 2.60093348237324
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.04545867311526
#  TRAIN MSE 1288.9591892764145
#  TEST MAPE 2.685295288389691
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.378967295600646
#  TRAIN MSE 1274.8809652027244
#  TEST MAPE 2.5151342468863627
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.01665481226539
#  TRAIN MSE 1245.4293001333472
#  TEST MAPE 2.5624774542669826
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 43.22647294177916
#  TRAIN MSE 1348.4641087459206
#  TEST MAPE 2.3467889677497684
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 51.31531221118427
#  TRAIN MSE 1314.1639638111196
#  TEST MAPE 2.7131395118582082
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.2144912879107
#  TRAIN MSE 1317.0092963378972
#  TEST MAPE 2.564040936601335
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.16679957389487
#  TRAIN MSE 1277.2797432006118
#  TEST MAPE 2.663826286274704
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.42595969997965
#  TRAIN MSE 1273.2067590747683
#  TEST MAPE 2.5170016448226016
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.51174103842811
#  TRAIN MSE 1326.326459436128
#  TEST MAPE 2.4711862024356552
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.77838195189888
#  TRAIN MSE 1417.958985871399
#  TEST MAPE 2.6911648330695814
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.569222771588066
#  TRAIN MSE 1260.8573430388738
#  TEST MAPE 2.5557036232350083
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.834982520184134
#  TRAIN MSE 1311.3531768692737
#  TEST MAPE 2.5005148528530867
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.026713576373176
#  TRAIN MSE 1316.57173958274
#  TEST MAPE 2.6478666178046013
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.23285281802961
#  TRAIN MSE 1309.8464598181663
#  TEST MAPE 2.5790207317402705
#
# (31.013384568209844, 1743.1387842653605, 41.75091357402088, 0.02352760398009854, 0.0009649917857600721, 0.6134261902043612)
# model rersult
#  test RMSE 41.75091357402088
#  test MAPE 2.3527603980098544
#  Daily_peak_test_RMSE 44.49161792562575
#  Daily_peak_test_MAPE 2.1570396037465454
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: RI,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: RI,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: RI,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.47428703735822
#  TRAIN MSE 700.5171261882654
#  TEST MAPE 2.6592651990484653
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.3260894880487
#  TRAIN MSE 646.6775377278682
#  TEST MAPE 2.4921997674339993
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.83328333395108
#  TRAIN MSE 668.3566250333835
#  TEST MAPE 2.7353045986211626
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.90500779982365
#  TRAIN MSE 679.3075950429738
#  TEST MAPE 2.6738393275230576
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.95829487835569
#  TRAIN MSE 756.4162036171412
#  TEST MAPE 2.765694859020521
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.25880828939517
#  TRAIN MSE 701.6122579398191
#  TEST MAPE 2.573587969189129
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.75052256120822
#  TRAIN MSE 649.781858503554
#  TEST MAPE 2.5589223211339367
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 35.26273077652965
#  TRAIN MSE 658.3285615273222
#  TEST MAPE 2.7088700245371253
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.86842963519213
#  TRAIN MSE 686.0783866830038
#  TEST MAPE 2.710717209356636
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.11231851354258
#  TRAIN MSE 710.8272858605021
#  TEST MAPE 2.570557861820534
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 31.9706929922758
#  TRAIN MSE 662.0177743009015
#  TEST MAPE 2.543283754203494
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.42754997097621
#  TRAIN MSE 703.998803895649
#  TEST MAPE 2.5784410047247857
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.08402364489804
#  TRAIN MSE 662.5574530832005
#  TEST MAPE 2.5943782937023983
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.549913660755024
#  TRAIN MSE 621.3009178843699
#  TEST MAPE 2.532150212063378
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.73362809364174
#  TRAIN MSE 676.6995055703882
#  TEST MAPE 2.5650072653023965
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.059234186560744
#  TRAIN MSE 658.2867091461044
#  TEST MAPE 2.498997186750705
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.72565273116651
#  TRAIN MSE 643.2103270736691
#  TEST MAPE 2.651121934438923
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.85781990735619
#  TRAIN MSE 615.6502410996227
#  TEST MAPE 2.638349444145336
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.51051044178133
#  TRAIN MSE 677.2830458629221
#  TEST MAPE 2.6692871387753083
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 33.081895006697195
#  TRAIN MSE 701.6335152069064
#  TEST MAPE 2.550771812296508
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.94052892915705
#  TRAIN MSE 643.6332846634082
#  TEST MAPE 2.5762837634966598
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.10619788087317
#  TRAIN MSE 659.7735668526508
#  TEST MAPE 2.5013769835507977
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.9919840470464
#  TRAIN MSE 644.8665484966491
#  TEST MAPE 2.5621033509181768
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.03931113818047
#  TRAIN MSE 648.9989374532016
#  TEST MAPE 2.521596911304925
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.3597196345598
#  TRAIN MSE 704.9148838589628
#  TEST MAPE 2.7071452099939974
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.34353104299423
#  TRAIN MSE 683.3136045521227
#  TEST MAPE 2.6438601105122883
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.8902888800324
#  TRAIN MSE 664.7923498070695
#  TEST MAPE 2.599478901407902
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.01462630920529
#  TRAIN MSE 647.4936889661188
#  TEST MAPE 2.5061249914546653
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 32.96306296910651
#  TRAIN MSE 655.8053600405901
#  TEST MAPE 2.5527466804792516
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 34.33219219989757
#  TRAIN MSE 676.3818645898119
#  TEST MAPE 2.703008910212788
#
# (21.957886802638438, 945.9906449198863, 30.756960918138294, 0.02368467803819773, 0.001037435933043169, 0.6193629409749971)
# model rersult
#  test RMSE 30.756960918138294
#  test MAPE 2.368467803819773
#  Daily_peak_test_RMSE 36.54379178762492
#  Daily_peak_test_MAPE 2.3278746779752693
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: SEMASS,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: SEMASS,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: SEMASS,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 81.5959744274211
#  TRAIN MSE 2957.2449676172687
#  TEST MAPE 3.778329235132364
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.48453768822864
#  TRAIN MSE 2899.9406625766774
#  TEST MAPE 3.700699361263481
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 82.40515368586551
#  TRAIN MSE 3187.345014265354
#  TEST MAPE 3.87542640039679
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.34469780670881
#  TRAIN MSE 2947.60097495284
#  TEST MAPE 3.657733432567793
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 91.44230346470262
#  TRAIN MSE 3851.2878093075615
#  TEST MAPE 4.219930953538001
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.17090681663592
#  TRAIN MSE 3104.901567102444
#  TEST MAPE 3.603419342760745
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.92152155958254
#  TRAIN MSE 2936.744951060086
#  TEST MAPE 3.706409344197201
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 82.17260307247832
#  TRAIN MSE 2903.0568653939176
#  TEST MAPE 3.843273976527098
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.90688633658779
#  TRAIN MSE 2975.2585327165752
#  TEST MAPE 3.8635921134717757
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 80.23496894165147
#  TRAIN MSE 2947.1146176581606
#  TEST MAPE 3.6945542244494463
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.98504949637294
#  TRAIN MSE 2842.4453163384765
#  TEST MAPE 3.664335272356182
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.76560561928795
#  TRAIN MSE 2958.507788389582
#  TEST MAPE 3.5906806421315287
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 76.91267654169589
#  TRAIN MSE 2787.4209866839283
#  TEST MAPE 3.6048110277496312
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 76.97408038323823
#  TRAIN MSE 2830.8158843652286
#  TEST MAPE 3.613336380886472
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.87311332741707
#  TRAIN MSE 2792.92095575536
#  TEST MAPE 3.7276386163973525
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 76.8315190280461
#  TRAIN MSE 2863.503793619742
#  TEST MAPE 3.5436596712097215
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.61361773368834
#  TRAIN MSE 2894.4164996772506
#  TEST MAPE 3.7218573752863993
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.2639989411304
#  TRAIN MSE 2742.2388602575925
#  TEST MAPE 3.669465849160526
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 81.77546231357711
#  TRAIN MSE 2920.4262468023453
#  TEST MAPE 3.8202852259856512
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 80.78734054713428
#  TRAIN MSE 3108.3959488143546
#  TEST MAPE 3.6300859572678106
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.9848179729948
#  TRAIN MSE 2830.4550059583908
#  TEST MAPE 3.577612493429858
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 77.5128676334823
#  TRAIN MSE 2846.5995366243105
#  TEST MAPE 3.5775267654300222
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.57562859625922
#  TRAIN MSE 2966.9815932353204
#  TEST MAPE 3.8531480189871936
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.19874267640171
#  TRAIN MSE 2869.613537663243
#  TEST MAPE 3.638492317589178
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 91.12115280890588
#  TRAIN MSE 3376.0153873451545
#  TEST MAPE 4.2224545967795235
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 81.99990164487211
#  TRAIN MSE 3315.9233572882276
#  TEST MAPE 3.8106628951289294
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 78.70174477640818
#  TRAIN MSE 3022.7101236716067
#  TEST MAPE 3.652971573709305
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 76.53684794012202
#  TRAIN MSE 2850.7574735056273
#  TEST MAPE 3.5523584507949297
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 79.90424313313082
#  TRAIN MSE 2915.75201913815
#  TEST MAPE 3.746794411818947
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 81.16525486041117
#  TRAIN MSE 3093.265836369428
#  TEST MAPE 3.8029098536271615
#
# (55.10973989309671, 5573.318746674912, 74.65466326141262, 0.034250518310507704, 0.002144286602440873, 0.5699280739810481)
# model rersult
#  test RMSE 74.65466326141262
#  test MAPE 3.4250518310507703
#  Daily_peak_test_RMSE 78.0902115206483
#  Daily_peak_test_MAPE 2.7157379185484776
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: TOTAL,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: TOTAL,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: TOTAL,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 561.0055892815545
#  TRAIN MSE 113850.0884213656
#  TEST MAPE 3.092206560913866
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 524.3949008387928
#  TRAIN MSE 119455.63369621673
#  TEST MAPE 2.9522480697083164
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 547.8098177610934
#  TRAIN MSE 113603.66050104801
#  TEST MAPE 2.9349463838649665
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 570.4340825819282
#  TRAIN MSE 121947.8694147437
#  TEST MAPE 2.986137090939011
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 566.3768014551711
#  TRAIN MSE 141976.65142673042
#  TEST MAPE 2.926184467823862
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 525.3730417147607
#  TRAIN MSE 127970.4149988145
#  TEST MAPE 2.8609195054852115
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 521.1868096588286
#  TRAIN MSE 113052.50200557051
#  TEST MAPE 2.882656063291802
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 554.5578289017559
#  TRAIN MSE 121746.68172445893
#  TEST MAPE 3.037702927433584
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 581.9487919207903
#  TRAIN MSE 125725.96257807768
#  TEST MAPE 3.09318001046154
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 555.2575385223646
#  TRAIN MSE 118235.913451709
#  TEST MAPE 2.9237695212177077
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 535.8248430765277
#  TRAIN MSE 110759.6866708066
#  TEST MAPE 2.9431113286468857
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 522.5728678506091
#  TRAIN MSE 117889.58057988259
#  TEST MAPE 2.8093908513360266
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 547.5923806843149
#  TRAIN MSE 116753.56413234017
#  TEST MAPE 2.9938905243175946
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 531.0392569960565
#  TRAIN MSE 109731.42585365141
#  TEST MAPE 2.8958629647343805
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 520.5884421239659
#  TRAIN MSE 117056.5265489472
#  TEST MAPE 2.8729296097744497
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 508.68402590560316
#  TRAIN MSE 116603.97284246897
#  TEST MAPE 2.8423037814655427
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 521.4515305241556
#  TRAIN MSE 118339.06269625905
#  TEST MAPE 2.9199176209919933
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 513.6488747105757
#  TRAIN MSE 114879.41324386903
#  TEST MAPE 2.8421708110326263
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 533.7479841947871
#  TRAIN MSE 108890.72336810025
#  TEST MAPE 2.921102177743499
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 586.3480129153604
#  TRAIN MSE 135738.48344395455
#  TEST MAPE 2.8810729040592613
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 537.4475310636745
#  TRAIN MSE 117488.9093105254
#  TEST MAPE 2.903322556152915
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 541.0158224326648
#  TRAIN MSE 122941.80625114412
#  TEST MAPE 3.00624378018272
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 542.0055349685182
#  TRAIN MSE 112444.28555046486
#  TEST MAPE 2.9628357603963744
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 510.88603804830245
#  TRAIN MSE 112858.47275200192
#  TEST MAPE 2.833227387862096
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 564.7717876151552
#  TRAIN MSE 127045.48370480594
#  TEST MAPE 2.8670151129487618
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 553.7923693466913
#  TRAIN MSE 134318.83247169422
#  TEST MAPE 2.9273930305723175
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 531.9501497893464
#  TRAIN MSE 112031.99911616775
#  TEST MAPE 2.860591667718511
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 515.2814482180868
#  TRAIN MSE 111326.59930062918
#  TEST MAPE 2.8425201812762686
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 531.8913388471394
#  TRAIN MSE 115932.10971788714
#  TEST MAPE 2.916190958615333
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 524.2806990065085
#  TRAIN MSE 116101.71746040058
#  TEST MAPE 2.8729632694920277
#
# (371.8963003925617, 245712.0537413849, 495.6935078668924, 0.026913692919655657, 0.001197191947470349, 0.5719831030939605)
# model rersult
#  test RMSE 495.6935078668924
#  test MAPE 2.691369291965566
#  Daily_peak_test_RMSE 540.8190760884886
#  Daily_peak_test_MAPE 2.26181524375925
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: VT,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: VT,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: VT,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.7846192762377
#  TRAIN MSE 575.8379907600489
#  TEST MAPE 6.171781498567052
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.25860323409539
#  TRAIN MSE 590.9423751958756
#  TEST MAPE 6.130682470840073
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.502114290968365
#  TRAIN MSE 565.6971524644129
#  TEST MAPE 6.283053681096296
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.691087911436064
#  TRAIN MSE 595.3239821938721
#  TEST MAPE 6.2034922806552
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.037637960574585
#  TRAIN MSE 603.548932588764
#  TEST MAPE 5.697569985911026
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.58953876935805
#  TRAIN MSE 622.5347390869906
#  TEST MAPE 6.28920191783513
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.309684364540416
#  TRAIN MSE 567.7508416755519
#  TEST MAPE 6.223844629249387
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.74214050353464
#  TRAIN MSE 585.0625312306689
#  TEST MAPE 6.448196633839675
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.63492401910611
#  TRAIN MSE 605.7880328870676
#  TEST MAPE 6.589227071986029
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.62626967094238
#  TRAIN MSE 614.9996955833792
#  TEST MAPE 6.1839589526901495
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.63599872668974
#  TRAIN MSE 593.069861471273
#  TEST MAPE 6.22445176400108
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.86458909361439
#  TRAIN MSE 604.2548017635398
#  TEST MAPE 6.019668305669094
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.06184979174986
#  TRAIN MSE 591.617880156377
#  TEST MAPE 6.408474552313518
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.21199036044203
#  TRAIN MSE 607.0154743045375
#  TEST MAPE 6.453171043894426
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.33103194342302
#  TRAIN MSE 576.0612464456653
#  TEST MAPE 6.318246828620164
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.487485434596245
#  TRAIN MSE 572.089281539232
#  TEST MAPE 6.510573961730826
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.80661405364859
#  TRAIN MSE 578.3217081227092
#  TEST MAPE 6.405911909265079
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.1060856801767
#  TRAIN MSE 556.1868653462047
#  TEST MAPE 6.434522130943831
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.874004263939135
#  TRAIN MSE 545.0350608833512
#  TEST MAPE 6.401927033902437
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.29809354320582
#  TRAIN MSE 606.7036920812989
#  TEST MAPE 5.672052320078635
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.03143121807614
#  TRAIN MSE 603.5021746700315
#  TEST MAPE 6.199520623715947
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 51.16493025172637
#  TRAIN MSE 583.1068949437478
#  TEST MAPE 6.686946074540515
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.224821518264044
#  TRAIN MSE 587.0273781162614
#  TEST MAPE 6.443011492046545
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.84508999702966
#  TRAIN MSE 574.7347384915294
#  TEST MAPE 6.318182652904348
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.622684361263815
#  TRAIN MSE 599.6972149918134
#  TEST MAPE 5.65909135678238
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.622517784698864
#  TRAIN MSE 587.6064816775504
#  TEST MAPE 6.051651048413414
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.13020911083163
#  TRAIN MSE 555.1813247594744
#  TEST MAPE 6.253250964272648
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.83943422687869
#  TRAIN MSE 565.7769480712068
#  TEST MAPE 6.226425504436356
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.410248667737214
#  TRAIN MSE 573.5954712263618
#  TEST MAPE 6.312466698791691
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.81460960034929
#  TRAIN MSE 588.4901281780673
#  TEST MAPE 6.3675524881755985
#
# (34.873410583062025, 1986.5978332847153, 44.571266902397056, 0.06077615430419988, 0.006847357487111492, 0.400502340449823)
# model rersult
#  test RMSE 44.571266902397056
#  test MAPE 6.077615430419988
#  Daily_peak_test_RMSE 31.16527414478098
#  Daily_peak_test_MAPE 3.3795272977894206
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: WCMASS,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: WCMASS,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: WCMASS,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 30
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 82.70073289882318
#  TRAIN MSE 3472.817202768937
#  TEST MAPE 3.1474445503871933
#
# seed 31
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 91.2746659845259
#  TRAIN MSE 3506.443696990889
#  TEST MAPE 3.391955764946992
#
# seed 32
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.59112804074626
#  TRAIN MSE 3410.1153246853482
#  TEST MAPE 3.305596786829
#
# seed 33
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.3808036082798
#  TRAIN MSE 3738.178485534503
#  TEST MAPE 3.4360995972333686
#
# seed 34
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 94.1400926710879
#  TRAIN MSE 3862.3922515976633
#  TEST MAPE 3.5764305806046255
#
# seed 35
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 81.4131795399394
#  TRAIN MSE 3400.552822734009
#  TEST MAPE 3.118211494269039
#
# seed 36
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.005212431594
#  TRAIN MSE 3488.9345675963996
#  TEST MAPE 3.2608548527929244
#
# seed 37
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.65026145638971
#  TRAIN MSE 3398.6740673094423
#  TEST MAPE 3.315674863443854
#
# seed 38
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 93.4749486555527
#  TRAIN MSE 3756.84751306797
#  TEST MAPE 3.5124913815049625
#
# seed 39
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 88.95211917995496
#  TRAIN MSE 3500.9468606885703
#  TEST MAPE 3.2882842514988733
#
# seed 40
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 86.01306869588322
#  TRAIN MSE 3541.892855459151
#  TEST MAPE 3.372117437087454
#
# seed 41
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.37840774236527
#  TRAIN MSE 3534.1594205420074
#  TEST MAPE 3.225605487449375
#
# seed 42
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.40203446784979
#  TRAIN MSE 3462.0460408963777
#  TEST MAPE 3.4499061276771887
#
# seed 43
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.85903022146435
#  TRAIN MSE 3289.945862679391
#  TEST MAPE 3.3335386667512643
#
# seed 44
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.91831867216673
#  TRAIN MSE 3357.540750332428
#  TEST MAPE 3.2815281269595777
#
# seed 45
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 83.48813692762488
#  TRAIN MSE 3458.4991295855225
#  TEST MAPE 3.281894082448513
#
# seed 46
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 90.31643772033448
#  TRAIN MSE 3652.2548217270783
#  TEST MAPE 3.4575810138609886
#
# seed 47
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 86.87448449800934
#  TRAIN MSE 3350.2845748792683
#  TEST MAPE 3.3333231766297073
#
# seed 48
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 96.02833130670123
#  TRAIN MSE 3499.9445384886662
#  TEST MAPE 3.5641676301502785
#
# seed 49
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 95.47277790523418
#  TRAIN MSE 3696.899195676848
#  TEST MAPE 3.4610230741270565
#
# seed 50
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 94.15919008994278
#  TRAIN MSE 3579.4423978009095
#  TEST MAPE 3.5553921207309034
#
# seed 51
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.45634817053961
#  TRAIN MSE 3479.855450293741
#  TEST MAPE 3.3484477731914986
#
# seed 52
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 95.14664668738408
#  TRAIN MSE 3441.793161986336
#  TEST MAPE 3.543747172708659
#
# seed 53
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 82.0004171170657
#  TRAIN MSE 3425.1052085821325
#  TEST MAPE 3.1820963256906296
#
# seed 54
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 97.64956058790443
#  TRAIN MSE 3838.7819284406946
#  TEST MAPE 3.6316354160175273
#
# seed 55
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 96.10329726266258
#  TRAIN MSE 3926.742368508805
#  TEST MAPE 3.597940857055257
#
# seed 56
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 83.85520503283934
#  TRAIN MSE 3292.86978554026
#  TEST MAPE 3.21863647669417
#
# seed 57
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 80.85941657538648
#  TRAIN MSE 3371.3857898846395
#  TEST MAPE 3.0845348811881927
#
# seed 58
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.4096903625349
#  TRAIN MSE 3539.2860584333416
#  TEST MAPE 3.3186464140649803
#
# seed 59
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.77280823010548
#  TRAIN MSE 3575.62238939991
#  TEST MAPE 3.4669382584698303
#
# (58.97910531458163, 6640.261592786194, 81.48780026964891, 0.030843182436692925, 0.001764675313218778, 0.5454960611942002)
# model rersult
#  test RMSE 81.48780026964891
#  test MAPE 3.0843182436692924
#  Daily_peak_test_RMSE 81.49395735237582
#  Daily_peak_test_MAPE 2.381015700279341
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: CT,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: CT,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: CT,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 60
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 144.76795386471508
#  TRAIN MSE 10658.280391194665
#  TEST MAPE 3.4329733754716334
#
# seed 61
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 151.66144206871152
#  TRAIN MSE 10323.301752195848
#  TEST MAPE 3.594674695616233
#
# seed 62
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 150.88366911011724
#  TRAIN MSE 11491.748466976449
#  TEST MAPE 3.1575842649885133
#
# seed 63
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 154.82309269774714
#  TRAIN MSE 10298.47707172036
#  TEST MAPE 3.6252802380229965
#
# seed 64
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 155.70831999925983
#  TRAIN MSE 11334.986155535364
#  TEST MAPE 3.5833242998572192
#
# seed 65
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.59134350290458
#  TRAIN MSE 10458.42465670377
#  TEST MAPE 3.503271126870342
#
# seed 66
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 145.6418607012196
#  TRAIN MSE 9898.257042416108
#  TEST MAPE 3.434885592984349
#
# seed 67
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 150.63523534382603
#  TRAIN MSE 11129.024317641602
#  TEST MAPE 3.5620534579754266
#
# seed 68
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 142.8333887868523
#  TRAIN MSE 11853.101068940035
#  TEST MAPE 3.0188101049589506
#
# seed 69
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 144.01000678624723
#  TRAIN MSE 10232.477291197874
#  TEST MAPE 3.4703588233880005
#
# seed 70
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 161.08126388487628
#  TRAIN MSE 10073.59511128845
#  TEST MAPE 3.76253001011314
#
# seed 71
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 162.11015844014793
#  TRAIN MSE 10209.370626982782
#  TEST MAPE 3.654116519517735
#
# seed 72
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.5230959400512
#  TRAIN MSE 10084.424773289675
#  TEST MAPE 3.558768271936097
#
# seed 73
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 136.289844246422
#  TRAIN MSE 11066.393815124207
#  TEST MAPE 2.9808681624917828
#
# seed 74
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 149.72083075464514
#  TRAIN MSE 10623.242202604
#  TEST MAPE 3.5405164755835203
#
# seed 75
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 144.50036012823188
#  TRAIN MSE 9810.702849436262
#  TEST MAPE 3.4323454775243607
#
# seed 76
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 157.4566616477798
#  TRAIN MSE 10498.53122038249
#  TEST MAPE 3.6005064598030048
#
# seed 77
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 147.58378381907025
#  TRAIN MSE 9646.913160081602
#  TEST MAPE 3.5173991651875465
#
# seed 78
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 147.35476045398534
#  TRAIN MSE 10258.30598578314
#  TEST MAPE 3.5415756911483194
#
# seed 79
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 146.3082345268997
#  TRAIN MSE 11081.723417060077
#  TEST MAPE 3.443239298017066
#
# seed 80
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 157.89772473992534
#  TRAIN MSE 10901.439189920333
#  TEST MAPE 3.3961034651793653
#
# seed 81
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.90316088211335
#  TRAIN MSE 10658.629464024028
#  TEST MAPE 3.511809048659277
#
# seed 82
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 140.45186940139948
#  TRAIN MSE 10588.410881170887
#  TEST MAPE 3.1609558765554975
#
# seed 83
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 147.53091776387856
#  TRAIN MSE 10306.813955140515
#  TEST MAPE 3.494095846876362
#
# seed 84
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 153.87236784256743
#  TRAIN MSE 11214.806893581934
#  TEST MAPE 3.5665842504227503
#
# seed 85
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 152.61181039602664
#  TRAIN MSE 10548.827695393938
#  TEST MAPE 3.619972589786623
#
# seed 86
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 148.64319023381458
#  TRAIN MSE 10631.306593180194
#  TEST MAPE 3.506057833173536
#
# seed 87
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 142.36743274280803
#  TRAIN MSE 11107.625210461012
#  TEST MAPE 3.2175504235292482
#
# seed 88
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 153.38772807846408
#  TRAIN MSE 11444.260885864918
# ...
# zone: TOTAL,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: TOTAL,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 270
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 520.3422927637325
#  TRAIN MSE 107494.61418212081
#  TEST MAPE 2.890516036415142
#
# seed 271
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 531.8737980714388
#  TRAIN MSE 114447.13666349371
#  TEST MAPE 2.941817062097993
#
# seed 272
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 543.940441753756
#  TRAIN MSE 113544.09024349942
#  TEST MAPE 2.9181693414880083
#
# seed 273
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 539.9004954715501
#  TRAIN MSE 117403.33968778483
#  TEST MAPE 2.9397003445073357
#
# seed 274
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 525.054089442993
#  TRAIN MSE 104236.55223964184
#  TEST MAPE 2.834897655704737
#
# seed 275
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 563.5249379467864
#  TRAIN MSE 125844.75673840131
#  TEST MAPE 3.0409473400464604
#
# seed 276
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 511.7089608191094
#  TRAIN MSE 113394.22068793279
#  TEST MAPE 2.806858920020728
#
# seed 277
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 530.7168316718204
#  TRAIN MSE 118782.74714810029
#  TEST MAPE 2.9033242231657255
#
# seed 278
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 543.990582967533
#  TRAIN MSE 117454.25620031968
#  TEST MAPE 2.9382540122128913
#
# seed 279
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 529.5286664740112
#  TRAIN MSE 111419.88194263425
#  TEST MAPE 2.9189637688335726
#
# seed 280
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 538.9474379080054
#  TRAIN MSE 115658.4761231964
#  TEST MAPE 2.988772416856109
#
# seed 281
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 578.7408646972815
#  TRAIN MSE 120486.03917907955
#  TEST MAPE 3.096436001825691
#
# seed 282
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 546.3935599279979
#  TRAIN MSE 114127.23714959878
#  TEST MAPE 2.9699268087835007
#
# seed 283
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 505.6727551017624
#  TRAIN MSE 109731.10575470972
#  TEST MAPE 2.7855119263104595
#
# seed 284
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 515.8555721875853
#  TRAIN MSE 117830.62177265032
#  TEST MAPE 2.81284101272506
#
# seed 285
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 508.0481982074631
#  TRAIN MSE 120168.99270748776
#  TEST MAPE 2.7300160180474298
#
# seed 286
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 537.0684938203159
#  TRAIN MSE 114372.96362799579
#  TEST MAPE 2.9433450846720737
#
# seed 287
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 532.2538017780502
#  TRAIN MSE 121844.78752966871
#  TEST MAPE 2.911221687680428
#
# seed 288
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 528.1800600703759
#  TRAIN MSE 115293.07188235974
#  TEST MAPE 2.8946127260002474
#
# seed 289
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 556.7912991722249
#  TRAIN MSE 103894.9623471323
#  TEST MAPE 2.9224607208946765
#
# seed 290
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 516.0493342582296
#  TRAIN MSE 107688.64342284137
#  TEST MAPE 2.86273292082985
#
# seed 291
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 547.8650705822238
#  TRAIN MSE 110716.94434191346
#  TEST MAPE 2.8977019323914934
#
# seed 292
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 541.2454829049503
#  TRAIN MSE 130076.9433122822
#  TEST MAPE 2.9422135663413576
#
# seed 293
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 515.4286334268129
#  TRAIN MSE 110996.12439643157
#  TEST MAPE 2.810864156958145
#
# seed 294
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 531.8980283416582
#  TRAIN MSE 111072.4673432881
#  TEST MAPE 2.9083111853551142
#
# seed 295
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 538.2309737791514
#  TRAIN MSE 111258.26593649194
#  TEST MAPE 2.9538109987002876
#
# seed 296
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 530.9116609185361
#  TRAIN MSE 117151.72376741219
#  TEST MAPE 2.8997011552990757
#
# seed 297
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 533.6358773069431
#  TRAIN MSE 112564.68292213712
#  TEST MAPE 2.9161902686594283
#
# seed 298
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 535.5911974205001
#  TRAIN MSE 115979.40825675782
#  TEST MAPE 2.913995225302014
#
# seed 299
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 511.5847803923432
#  TRAIN MSE 116100.41840926411
#  TEST MAPE 2.833609701855753
#
# (378.03879957374306, 250260.91120415783, 500.2608431650011, 0.027506926173437564, 0.0012363282797371476, 0.5682155497202876)
# model rersult
#  test RMSE 500.2608431650011
#  test MAPE 2.7506926173437565
#  Daily_peak_test_RMSE 543.4851423830764
#  Daily_peak_test_MAPE 2.27767961158782
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: VT,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: VT,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: VT,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 270
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.33276358026059
#  TRAIN MSE 582.2336264183045
#  TEST MAPE 6.177280561805083
#
# seed 271
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.790447586268954
#  TRAIN MSE 594.7260585037501
#  TEST MAPE 6.068559761539912
#
# seed 272
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.04223535623449
#  TRAIN MSE 602.3899398085161
#  TEST MAPE 6.284253730588349
#
# seed 273
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.089584679241675
#  TRAIN MSE 573.3556050198398
#  TEST MAPE 6.271376333439753
#
# seed 274
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.16061594302349
#  TRAIN MSE 587.8202037670919
#  TEST MAPE 6.320930950169644
#
# seed 275
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.973442433848206
#  TRAIN MSE 579.4886713718021
#  TEST MAPE 6.286612905172434
#
# seed 276
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.80179414528493
#  TRAIN MSE 605.8146203449844
#  TEST MAPE 6.225768386166002
#
# seed 277
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.95489517406104
#  TRAIN MSE 603.2638515073348
#  TEST MAPE 6.313563192147735
#
# seed 278
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.76641199918477
#  TRAIN MSE 550.7183859553666
#  TEST MAPE 6.261929683699753
#
# seed 279
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.462767221295515
#  TRAIN MSE 559.5633107577329
#  TEST MAPE 6.215919731390822
#
# seed 280
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.019549144391824
#  TRAIN MSE 595.35422582633
#  TEST MAPE 6.364332921470363
#
# seed 281
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.687062936888644
#  TRAIN MSE 603.0778268495894
#  TEST MAPE 6.327362849283312
#
# seed 282
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.23810883057486
#  TRAIN MSE 571.5841678686048
#  TEST MAPE 6.465548116999124
#
# seed 283
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.54327332524207
#  TRAIN MSE 561.6782184349638
#  TEST MAPE 6.410627911034274
#
# seed 284
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.23163513121144
#  TRAIN MSE 596.2135865569223
#  TEST MAPE 5.989625241522577
#
# seed 285
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.5338503014105
#  TRAIN MSE 578.0070029964676
#  TEST MAPE 5.968430800061304
#
# seed 286
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.91858393952331
#  TRAIN MSE 596.717746000142
#  TEST MAPE 6.30296959478028
#
# seed 287
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.013332270357864
#  TRAIN MSE 595.6925540875841
#  TEST MAPE 6.291979011346016
#
# seed 288
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.120617721292604
#  TRAIN MSE 583.906429994858
#  TEST MAPE 6.151492454855612
#
# seed 289
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.32664173884013
#  TRAIN MSE 558.0994840840426
#  TEST MAPE 6.519151930666331
#
# seed 290
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 49.093529478698144
#  TRAIN MSE 548.5143285570023
#  TEST MAPE 6.496379040469806
#
# seed 291
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.81885852343011
#  TRAIN MSE 557.6323839932343
#  TEST MAPE 6.467742428247629
#
# seed 292
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.93500251737484
#  TRAIN MSE 607.2313036921634
#  TEST MAPE 5.928737599844111
#
# seed 293
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.334405705594925
#  TRAIN MSE 586.2828504581099
#  TEST MAPE 6.080186152734446
#
# seed 294
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 44.87100719279146
#  TRAIN MSE 586.4740467399982
#  TEST MAPE 6.193580514079622
#
# seed 295
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 46.98200351718194
#  TRAIN MSE 552.7296821840114
#  TEST MAPE 6.33530145008402
#
# seed 296
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.37107116914184
#  TRAIN MSE 550.7856295678066
#  TEST MAPE 6.345328432736263
#
# seed 297
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 45.75782850563051
#  TRAIN MSE 569.364159199257
#  TEST MAPE 6.312264239360878
#
# seed 298
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 47.676441353706714
#  TRAIN MSE 565.9381180287683
#  TEST MAPE 6.3985914627393825
#
# seed 299
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 48.95068139214282
#  TRAIN MSE 586.0305930478327
#  TEST MAPE 6.625270686071126
#
# (35.16523300492395, 1989.94662770319, 44.60881782454216, 0.06119909840662496, 0.0068221754696844794, 0.39410891654298436)
# model rersult
#  test RMSE 44.60881782454216
#  test MAPE 6.119909840662496
#  Daily_peak_test_RMSE 31.88554088072502
#  Daily_peak_test_MAPE 3.4556384880338764
#
# Total Set, (Nums, Variables): (40819, 157)
# zone: WCMASS,
# 	 Train start: 2015-01-01 00:00:00,
# 	 Train end: 2017-01-01 00:00:00
# zone: WCMASS,
# 	 Valid start: 2017-01-01 00:00:00,
# 	 Valid end: 2018-01-01 00:00:00
# zone: WCMASS,
# 	 Test start: 2018-01-01 00:00:00,
# 	 Test end: 2019-01-01 00:00:00
# Train set: (17540, 155)
# Valid set: (8760, 155)
# Test set: (8760, 155)
# seed 270
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.50071063217862
#  TRAIN MSE 3404.1049386761842
#  TEST MAPE 3.218095633074061
#
# seed 271
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 83.54356849597336
#  TRAIN MSE 3472.781301689479
#  TEST MAPE 3.2034583898409434
#
# seed 272
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 88.11495878006517
#  TRAIN MSE 3523.949660960262
#  TEST MAPE 3.3875950683422826
#
# seed 273
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 98.17294194860253
#  TRAIN MSE 3629.759942613505
#  TEST MAPE 3.588218823853305
#
# seed 274
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.0011951797333
#  TRAIN MSE 3326.885449192455
#  TEST MAPE 3.2283488846855226
#
# seed 275
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 97.94360213832819
#  TRAIN MSE 3843.659680019316
#  TEST MAPE 3.583100039342859
#
# seed 276
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.80142391937537
#  TRAIN MSE 3437.485779601041
#  TEST MAPE 3.286801344061146
#
# seed 277
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 87.9357964276244
#  TRAIN MSE 3539.927762391308
#  TEST MAPE 3.393313062338371
#
# seed 278
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.47297953881495
#  TRAIN MSE 3601.7445392369136
#  TEST MAPE 3.247622335545223
#
# seed 279
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 95.74546017631819
#  TRAIN MSE 3418.401645405413
#  TEST MAPE 3.5420601316492393
#
# seed 280
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 94.84756245130585
#  TRAIN MSE 3758.746467367803
#  TEST MAPE 3.639844490781779
#
# seed 281
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.36865516317455
#  TRAIN MSE 3678.213977580902
#  TEST MAPE 3.4289537911578365
#
# seed 282
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 93.48853421582972
#  TRAIN MSE 3481.097629452375
#  TEST MAPE 3.4797769698542114
#
# seed 283
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 83.56640264729825
#  TRAIN MSE 3376.1314859112354
#  TEST MAPE 3.2116898786679386
#
# seed 284
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.41681132598899
#  TRAIN MSE 3887.8667846742464
#  TEST MAPE 3.3586264940116677
#
# seed 285
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 86.05535626539873
#  TRAIN MSE 3581.544132173015
#  TEST MAPE 3.2353039570874786
#
# seed 286
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 91.26541380282734
#  TRAIN MSE 3442.8891320823864
#  TEST MAPE 3.3591629779546044
#
# seed 287
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 88.2375762661627
#  TRAIN MSE 3530.5917385649504
#  TEST MAPE 3.3917744817161095
#
# seed 288
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 88.47636132072408
#  TRAIN MSE 3676.5824338352454
#  TEST MAPE 3.38708222301807
#
# seed 289
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 97.73492346355653
#  TRAIN MSE 3300.58632535553
#  TEST MAPE 3.5927278629259747
#
# seed 290
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.44875504663047
#  TRAIN MSE 3347.6411168453824
#  TEST MAPE 3.3270051360209942
#
# seed 291
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 83.54168795806008
#  TRAIN MSE 3397.0169573088983
#  TEST MAPE 3.218315264345025
#
# seed 292
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 93.77344589165311
#  TRAIN MSE 3833.86607631592
#  TEST MAPE 3.5002314874699474
#
# seed 293
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 86.61570226469364
#  TRAIN MSE 3426.4166985932648
#  TEST MAPE 3.3153746561249453
#
# seed 294
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 84.23401886889553
#  TRAIN MSE 3512.655103191962
#  TEST MAPE 3.2567435978590393
#
# seed 295
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 86.37494487478286
#  TRAIN MSE 3409.860187662994
#  TEST MAPE 3.403482396137049
#
# seed 296
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.70317045898629
#  TRAIN MSE 3387.8239779613905
#  TEST MAPE 3.2907924504244206
#
# seed 297
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 89.72472734727067
#  TRAIN MSE 3323.7016255521753
#  TEST MAPE 3.338218812704398
#
# seed 298
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 94.94192123663677
#  TRAIN MSE 3485.3537100411486
#  TEST MAPE 3.5418123896726454
#
# seed 299
# you are using: cuda
# epoch 20 EPOCH 100
#  TEST RMSE 85.19436409448345
#  TRAIN MSE 3503.176563543115
#  TEST MAPE 3.2958101311474115
#
# (59.0998557765797, 6660.631297846464, 81.61269078915646, 0.03096580597984104, 0.0017658452120653029, 0.5420710126726795)
# model rersult
#  test RMSE 81.61269078915646
#  test MAPE 3.096580597984104
#  Daily_peak_test_RMSE 81.85264505037873
#  Daily_peak_test_MAPE 2.3533980778689045
#
# Test RMSE of experiment
#                   mean       std
# zone
# CT          138.989374  1.316829
# ME           63.799874  0.778075
# NEMASSBOST  114.709972  0.473353
# NH           41.677467  0.200493
# RI           30.850795  0.063577
# SEMASS       74.950736  0.223685
# TOTAL       494.528163  3.570546
# VT           44.536746  0.176841
# WCMASS       81.801698  0.592994
# Test MAPE of experiment
#                 mean       std
# zone
# CT          3.264478  0.044813
# ME          3.799018  0.052638
# NEMASSBOST  3.121657  0.032163
# NH          2.355793  0.015217
# RI          2.378951  0.005821
# SEMASS      3.448340  0.018199
# TOTAL       2.703114  0.025666
# VT          6.081868  0.031064
# WCMASS      3.093211  0.018581
# Test Daily peak RMSE of experiment
#                   mean       std
# zone
# CT          151.564129  1.821921
# ME           72.099766  0.909445
# NEMASSBOST  133.930064  0.436970
# NH           44.538436  0.342029
# RI           36.602719  0.121305
# SEMASS       78.559202  0.454157
# TOTAL       535.813916  5.990697
# VT           31.095683  0.469776
# WCMASS       81.772024  0.551351
# Test Daily peak MAPE of experiment
#                 mean       std
# zone
# CT          2.706432  0.040294
# ME          3.741103  0.049887
# NEMASSBOST  2.979935  0.018973
# NH          2.160268  0.019641
# RI          2.338681  0.014518
# SEMASS      2.725719  0.014772
# TOTAL       2.243213  0.021997
# VT          3.385227  0.050527
# WCMASS      2.371662  0.021829

# %%
df_results
# Out:
#           zone   test_RMSE  test_MAPE  Daily_peak_test_RMSE  \
# 0           CT  138.292549   3.207360            151.639844
# 1           ME   62.677603   3.717380             70.758929
# 2   NEMASSBOST  113.932112   3.058870            134.707306
# 3           NH   41.310698   2.328099             44.172534
# 4           RI   30.818148   2.372297             36.731889
# ..         ...         ...        ...                   ...
# 85          RI   30.835606   2.378872             36.608726
# 86      SEMASS   75.386980   3.475959             78.971432
# 87       TOTAL  500.260843   2.750693            543.485142
# 88          VT   44.608818   6.119910             31.885541
# 89      WCMASS   81.612691   3.096581             81.852645
#
#     Daily_peak_test_MAPE  seed_group
# 0               2.678079           0
# 1               3.675196           0
# 2               2.951097           0
# 3               2.146251           0
# 4               2.347978           0
# ..                   ...         ...
# 85              2.324690           9
# 86              2.723443           9
# 87              2.277680           9
# 88              3.455638           9
# 89              2.353398           9
#
# [90 rows x 6 columns]

# %%
start_year = 2015
num_subepoch = 20
num_epoch = 100
import time
printstride = 200
ensemble_times = 100

df_list_baseline_results = []
seed_group0 = 0
run_times = 100

seed_list = (np.arange(run_times * ensemble_times).reshape(run_times, ensemble_times)).astype(int)

path = f"./results/EnsembleGraph.pkl"

saved_dict_ens = {}

zone = 'CT'

X_train, y_train, X_valid, y_valid, X_test, y_test = get_zone_train(
    df, df2, zone=zone,
    train_start = pd.Timestamp(start_year, 1, 1),
    train_end = pd.Timestamp(start_year + 2, 1, 1),
    valid_start = pd.Timestamp(start_year + 2, 1, 1),
    valid_end = pd.Timestamp(start_year + 3, 1, 1),
    test_start = pd.Timestamp(start_year + 3, 1, 1),
    test_end = pd.Timestamp(start_year + 4, 1, 1),
    log=True, num_hour = 24, num_day = 7, 
    num_hour_RH = 3, num_day_RH = 1, RH = True
)

train_features = X_train.astype(np.float64)
valid_features = X_valid.astype(np.float64)
test_features = X_test.astype(np.float64)

train_labels = y_train.astype(np.float64)
valid_labels = y_valid.astype(np.float64)
test_labels = y_test.astype(np.float64)

[m_train, n_train] = train_features.shape
[m_valid, n_valid] = valid_features.shape
[m_test, n_test] = test_features.shape

# normalization
X_all = np.concatenate((train_features, valid_features, test_features), axis = 0)
m = X_all.shape[0]
mins = np.min(X_all[0:(m_train + m_valid), :], axis = 0)
maxs = np.max(X_all[0:(m_train + m_valid), :], axis = 0)

for i in range(m):
    X_all[i,:] = ( X_all[i,:] - mins ) / ( maxs - mins )

train_features = X_all[:m_train, :]
valid_features = X_all[m_train:(m_train + m_valid), :]
test_features = X_all[(m_train + m_valid) : , : ]

X_train_valid = np.concatenate((train_features, valid_features), axis = 0)
y_train_valid = np.concatenate((train_labels, valid_labels), axis = 0)      

for seed_group in range(seed_group0, seed_group0 + run_times):

    pre_test_ensemble_list = []
    saved_dict_sub = {}
    
    for i in range(ensemble_times):
        saved_dict_single = {}
        seed = seed_list[seed_group][i]

        time_start = time.time()
        predict_y_test = AltPolyRepeat(seed, X_train_valid, y_train_valid, test_features, test_labels, num_subepoch, num_epoch, printstride, device = 'cuda')
        time_end = time.time()

        pre_test_ensemble_list.append(predict_y_test)
        pre_tem = np.array(pre_test_ensemble_list).mean(axis = 0) 

        ens_test_RMSE = RMSE(pre_tem.reshape(test_labels.shape), test_labels)
        ens_test_MAPE = MAPE(pre_tem.reshape(test_labels.shape), test_labels)*100

        ens_Daily_peak_test_RMSE = RMSE( np.max(pre_tem.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )
        ens_Daily_peak_test_MAPE = MAPE( np.max(pre_tem.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )*100

        single_test_RMSE = RMSE(predict_y_test.reshape(test_labels.shape), test_labels)
        single_test_MAPE = MAPE(predict_y_test.reshape(test_labels.shape), test_labels)*100

        single_Daily_peak_test_RMSE = RMSE( np.max(predict_y_test.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )
        single_Daily_peak_test_MAPE = MAPE( np.max(predict_y_test.reshape(-1, 24), axis = 1), np.max(test_labels.reshape(-1, 24), axis = 1) )*100

        saved_dict_single['seed_group'] = seed_group
        saved_dict_single['ensemble times'] = i

        saved_dict_single['times'] = time_end - time_start

        saved_dict_single['ens_test_RMSE'] = ens_test_RMSE
        saved_dict_single['ens_test_MAPE'] = ens_test_MAPE
        saved_dict_single['ens_Daily_peak_test_RMSE'] = ens_Daily_peak_test_RMSE
        saved_dict_single['ens_Daily_peak_test_MAPE'] = ens_Daily_peak_test_MAPE

        saved_dict_single['single_test_RMSE'] = single_test_RMSE
        saved_dict_single['single_test_MAPE'] = single_test_MAPE
        saved_dict_single['single_Daily_peak_test_RMSE'] = single_Daily_peak_test_RMSE
        saved_dict_single['single_Daily_peak_test_MAPE'] = single_Daily_peak_test_MAPE

        saved_dict_sub[f"ensemble time_{i}"] = saved_dict_single

        print('seed_group', seed_group)
        print('ensemble times', i)
        print('conduct time', time_end - time_start)
        print( 'Single RMSE', single_test_RMSE )
        print( 'Single Daily_peak_test_MAPE', single_Daily_peak_test_MAPE )
        print( 'Ensemble RMSE', ens_test_RMSE )
        print( 'Ensemble Daily_peak_test_MAPE', ens_Daily_peak_test_MAPE )

    # 假设模型训练完成后，进行显存清理
    torch.cuda.empty_cache()

    # Checkpoint
    saved_dict_ens[f"seed_group_{seed_group}"] = saved_dict_sub
    with open(path, "wb") as f:
        pickle.dump(saved_dict_ens,
                    f,
                    protocol=pickle.HIGHEST_PROTOCOL)
